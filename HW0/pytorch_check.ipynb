# %%
import torch

print(f"My name is Devansh Mayatra")
print(f"UID: 122990357\n")

print("PyTorch Version: ", torch.version) 
print("GPU Available: ", torch.cuda.is_available())
# Out:
# My name is Devansh Mayatra
# UID: 122990357
#
# PyTorch Version:  <module 'torch.version' from '/home/devansh/miniconda3/envs/data-602/lib/python3.12/site-packages/torch/version.py'>
# GPU Available:  True
