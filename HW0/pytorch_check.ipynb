# %%
import torch

print(f"My name is Devansh Mayatra")
print(f"UID: 122990357")

print(f"Pytorch version: {torch.__version__},Cuda Availability: {torch.cuda.is_available()}")
# Out:
# My name is Devansh Mayatra
# UID: 122990357
# Pytorch version: 2.12.0.dev20260408+cu128,Cuda Availability: True
